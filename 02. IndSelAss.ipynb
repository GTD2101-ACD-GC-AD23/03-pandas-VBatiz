# %% [markdown]
# # Indexando, Seleccionando y Asignando datos
#
# En este JNB se revisará el tema de Indexamiento, Selección y Asignación de datos en Pandas

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd

# %%
reviews = pd.read_csv("./data/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews.province
# Out:
# 0         Sicily & Sardinia
# 1                     Douro
# 2                    Oregon
# 3                  Michigan
# 4                    Oregon
#                 ...
# 129966                Mosel
# 129967               Oregon
# 129968               Alsace
# 129969               Alsace
# 129970               Alsace
# Name: province, Length: 129971, dtype: object

# %%
reviews['winery']
# Out:
# 0                                          Nicosia
# 1                              Quinta dos Avidagos
# 2                                        Rainstorm
# 3                                       St. Julian
# 4                                     Sweet Cheeks
#                             ...
# 129966    Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                    Citation
# 129968                             Domaine Gresser
# 129969                        Domaine Marcel Deiss
# 129970                            Domaine Schoffit
# Name: winery, Length: 129971, dtype: object

# %%
reviews.iloc[100]
# Out:
# country                                                                 US
# description              Fresh apple, lemon and pear flavors are accent...
# designation                                                            NaN
# points                                                                  88
# price                                                                 18.0
# province                                                          New York
# region_1                                                      Finger Lakes
# region_2                                                      Finger Lakes
# taster_name                                             Anna Lee C. Iijima
# taster_twitter_handle                                                  NaN
# title                               Ventosa 2015 Pinot Gris (Finger Lakes)
# variety                                                         Pinot Gris
# ...

# %%
reviews.iloc[:10, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# 6       Italy
# 7      France
# 8     Germany
# 9      France
# Name: country, dtype: object

# %%
reviews.loc[:, ['title','taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                                                     title         taster_name  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)       Kerin O’Keefe
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)          Roger Voss
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)        Paul Gregutt
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...  Alexander Peartree
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...        Paul Gregutt
# ...                                                   ...                 ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...  Anna Lee C. Iijima
# 129967                  Citation 2004 Pinot Noir (Oregon)        Paul Gregutt
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...          Roger Voss
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Roger Voss
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...          Roger Voss
#
# ...

# %%
reviews.loc[reviews.country == 'Mexico']
# Out:
#        country                                        description  \
# 378     Mexico  The color is appropriately light, the aromas a...
# 601     Mexico  Sauvignon Blanc is, in general, one of Baja's ...
# 2692    Mexico  Aromas of mature Cabernet: cassis, tobacco lea...
# 6639    Mexico  While this is fiery on the nose, you also get ...
# 7608    Mexico  Dark and earthy, slightly pruny and alcoholic,...
# ...        ...                                                ...
# 116975  Mexico  This is light on the nose, with almost airy ar...
# 121135  Mexico  Pithy, citrusy aromas are about all the nose o...
# 124237  Mexico  This rusty looking, aged Cabernet Sauvignon di...
# 125495  Mexico  This Cabernet blend is one of Baja's best reds...
# 125824  Mexico  Slightly sweet on the nose, but wheaty and gra...
#
#                         designation  points  price  \
# 378                 Private Reserve      88   18.0
# 601                    Viña Kristel      87   15.0
# ...

# %%
reviews.loc[reviews.points > 99]
# Out:
#           country                                        description  \
# 345     Australia  This wine contains some material over 100 year...
# 7335        Italy  Thick as molasses and dark as caramelized brow...
# 36528      France  This is a fabulous wine from the greatest Cham...
# 39286       Italy  A perfect wine from a classic vintage, the 200...
# 42197    Portugal  This is the latest release of what has long be...
# 45781       Italy  This gorgeous, fragrant wine opens with classi...
# 45798          US  Tasted in a flight of great and famous Napa wi...
# 58352      France  This is a magnificently solid wine, initially ...
# 89728      France  This latest incarnation of the famous brand is...
# 89729      France  This new release from a great vintage for Char...
# 111753     France  Almost black in color, this stunning wine is g...
# 111754      Italy  It takes only a few moments before you appreci...
# 111755     France  This is the finest Cheval Blanc for many years...
# ...

# %%
reviews.loc[(reviews.country == 'Mexico') & (reviews.points >= 95)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
reviews.loc[reviews.country.isin(['Mexico', 'Argentina'])]
# Out:
#           country                                        description  \
# 16      Argentina  Baked plum, molasses, balsamic vinegar and che...
# 17      Argentina  Raw black-cherry aromas are direct and simple ...
# 183     Argentina  With attractive melon and other tropical aroma...
# 224     Argentina  Blackberry and road-tar aromas are dark and st...
# 231     Argentina  Meaty and rubbery, but that's young Bonarda. T...
# ...           ...                                                ...
# 129921  Argentina  There is a select group of under-$20 Malbecs f...
# 129925  Argentina  A lively, well-made blend of Tempranillo, Malb...
# 129932  Argentina  Andeluna's top wines tend to be ripe and plump...
# 129938  Argentina  Compared to the regular 2006 Malbec from Chaka...
# 129948  Argentina  Raspberry and cassis aromas are fresh and upri...
#
#                 designation  points  price          province       region_1  \
# ...
